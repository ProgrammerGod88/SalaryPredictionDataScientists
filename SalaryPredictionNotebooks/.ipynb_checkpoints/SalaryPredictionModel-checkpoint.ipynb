# %%
# Data manipulation and analysis
import pandas as pd
import numpy as np

# Data visualization
import matplotlib.pyplot as plt

# Scikit-learn for preprocessing and model evaluation
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.pipeline import Pipeline

# TensorFlow and Keras for building the deep learning model
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Embedding, LeakyReLU, Input
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2

# %%
df = pd.read_csv("/mnt/d/SalaryPredictionDataScientists/SalariesData/DataScience_salaries_2024.csv")

# %%
df.head()
# Out:
#    work_year experience_level employment_type                       job_title  \
# 0       2021               MI              FT                  Data Scientist
# 1       2021               MI              FT                 BI Data Analyst
# 2       2020               MI              FT                  Data Scientist
# 3       2021               MI              FT                     ML Engineer
# 4       2022               SE              FT  Lead Machine Learning Engineer
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  30400000             CLP          40038                 CL           100
# 1  11000000             HUF          36259                 HU            50
# 2  11000000             HUF          35735                 HU            50
# 3   8500000             JPY          77364                 JP            50
# 4   7500000             INR          95386                 IN            50
#
#   company_location company_size
# 0               CL            L
# 1               US            L
# 2               HU            L
# 3               JP            S
# 4               IN            L

# %%
# Check for missing values and data types
print("Dataset information:")
df.info()
# Out:
# Dataset information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14838 entries, 0 to 14837
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           14838 non-null  int64
#  1   experience_level    14838 non-null  object
#  2   employment_type     14838 non-null  object
#  3   job_title           14838 non-null  object
#  4   salary              14838 non-null  int64
#  5   salary_currency     14838 non-null  object
#  6   salary_in_usd       14838 non-null  int64
#  7   employee_residence  14838 non-null  object
#  8   remote_ratio        14838 non-null  int64
#  9   company_location    14838 non-null  object
#  10  company_size        14838 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 1.2+ MB

# %%
print("Summary statistics:")
df.describe()
# Out:
# Summary statistics:
#           work_year        salary  salary_in_usd  remote_ratio
# count  14838.000000  1.483800e+04   14838.000000  14838.000000
# mean    2023.138900  1.650227e+05  149874.718763     32.760480
# std        0.700799  3.562354e+05   69009.181349     46.488278
# min     2020.000000  1.400000e+04   15000.000000      0.000000
# 25%     2023.000000  1.021000e+05  102000.000000      0.000000
# 50%     2023.000000  1.422000e+05  141300.000000      0.000000
# 75%     2024.000000  1.875000e+05  185900.000000    100.000000
# max     2024.000000  3.040000e+07  800000.000000    100.000000

# %%
# Check for missing values in each column
print("Missing values per column:")
print(df.isnull().sum())
# Out:
# Missing values per column:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
#Pre-processing if needed for the given dataset

# Define columns based on data type
numerical_features = ['salary_in_usd']  # Add any other numerical columns if they exist
categorical_features = ['experience_level', 'employment_type', 'job_title', 'employee_residence']

# Fill missing numerical values with the median, and categorical with the most frequent value
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median'))
])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OneHotEncoder(handle_unknown='ignore'))
])

# Combine transformations into a preprocessor
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_features),
        ('cat', categorical_transformer, categorical_features)
    ]
)

# %%
# Transform categorical variables and prepare feature matrix X and target variable y
X = df.drop(columns=['salary'])  # Remove target column from features
y = df['salary_in_usd']  # Define target variable

# Apply transformations to features
X_prepared = preprocessor.fit_transform(X)

# Check the shape of the transformed features
print("Shape of transformed features:", X_prepared.shape)
# Out:
# Shape of transformed features: (14838, 250)

# %%
# Standardize the numerical features with with_mean=False
scaler = StandardScaler(with_mean=False)  # Set with_mean=False to handle sparse matrices
X_prepared = scaler.fit_transform(X_prepared)

# Check the first few rows to confirm transformation
print("Transformed feature matrix:")
print(X_prepared[:5])
# Out:
# Transformed feature matrix:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 25 stored elements and shape (5, 250)>
#   Coords	Values
#   (0, 0)	0.5802032201608008
#   (0, 3)	2.3432950833186106
#   (0, 7)	15.027396638488266
#   (0, 98)	2.485237303206165
#   (0, 177)	86.1394226519265
#   (1, 0)	0.5254405454770587
#   (1, 3)	2.3432950833186106
#   (1, 7)	15.027396638488266
#   (1, 30)	27.96334476701327
#   (1, 200)	60.913875838357235
#   (2, 0)	0.5178470970689399
#   (2, 3)	2.3432950833186106
#   (2, 7)	15.027396638488266
#   (2, 98)	2.485237303206165
#   (2, 200)	60.913875838357235
#   (3, 0)	1.1211059974154602
#   (3, 3)	2.3432950833186106
#   (3, 7)	15.027396638488266
#   (3, 123)	9.593840845668065
#   (3, 209)	43.07842313092561
#   (4, 0)	1.3822684539252246
#   (4, 4)	2.101420802721994
#   (4, 7)	15.027396638488266
#   (4, 122)	54.48486337586088
#   (4, 204)	14.195722091719437

# %%
# Split data into training and test sets (80-20 split)
X_train, X_test, y_train, y_test = train_test_split(X_prepared, y, test_size=0.2, random_state=42)

# Check the shape of each set
print("Training set shape:", X_train.shape, y_train.shape)
print("Testing set shape:", X_test.shape, y_test.shape)
# Out:
# Training set shape: (11870, 250) (11870,)
# Testing set shape: (2968, 250) (2968,)

# %%
# Save processed data to .npz files
np.savez("processed_data.npz", X_train=X_train, X_test=X_test, y_train=y_train, y_test=y_test)

# %%
# Define the model architecture
model = Sequential([
    Input(shape=(X_train.shape[1],)), 
    Dense(256, kernel_regularizer=l2(0.001)),
    LeakyReLU(negative_slope=0.1), 
    Dropout(0.3),
    
    Dense(128, kernel_regularizer=l2(0.001)),
    LeakyReLU(negative_slope=0.1), 
    Dropout(0.3),
    
    Dense(64, kernel_regularizer=l2(0.001)),
    LeakyReLU(negative_slope=0.1),  
    Dense(1) 
])
# Out:
# W0000 00:00:1730130859.762055     806 gpu_device.cc:2344] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0005),
              loss='mean_squared_error',
              metrics=['mean_absolute_error'])

# %%
# Train the model
history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    verbose=1
)
# Out:
# Epoch 1/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 25544896512.0000 - mean_absolute_error: 144019.2812 - val_loss: 5669242880.0000 - val_mean_absolute_error: 55554.7188
# Epoch 2/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 4331609600.0000 - mean_absolute_error: 48251.7227 - val_loss: 3048094208.0000 - val_mean_absolute_error: 41573.4883
# Epoch 3/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3438869760.0000 - mean_absolute_error: 42591.6641 - val_loss: 2542851840.0000 - val_mean_absolute_error: 37799.4961
# Epoch 4/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2770755072.0000 - mean_absolute_error: 38335.5391 - val_loss: 2183312896.0000 - val_mean_absolute_error: 34472.1367
# Epoch 5/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2332646912.0000 - mean_absolute_error: 35537.0430 - val_loss: 1908810496.0000 - val_mean_absolute_error: 31898.8008
# Epoch 6/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1916285952.0000 - mean_absolute_error: 32429.7402 - val_loss: 1651181952.0000 - val_mean_absolute_error: 30027.7637
# Epoch 7/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1873014272.0000 - mean_absolute_error: 31296.7637 - val_loss: 1408159104.0000 - val_mean_absolute_error: 27528.7754
# Epoch 8/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1408426624.0000 - mean_absolute_error: 28095.5684 - val_loss: 1127539072.0000 - val_mean_absolute_error: 24932.1035
# Epoch 9/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1264319616.0000 - mean_absolute_error: 25989.4277 - val_loss: 828035584.0000 - val_mean_absolute_error: 21419.8047
# Epoch 10/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 966306816.0000 - mean_absolute_error: 22548.6914 - val_loss: 518763712.0000 - val_mean_absolute_error: 16882.2715
# Epoch 11/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 683866880.0000 - mean_absolute_error: 18837.5938 - val_loss: 259312944.0000 - val_mean_absolute_error: 11943.4580
# Epoch 12/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 364127264.0000 - mean_absolute_error: 14345.7363 - val_loss: 102446120.0000 - val_mean_absolute_error: 7322.7524
# Epoch 13/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 262194096.0000 - mean_absolute_error: 11895.5068 - val_loss: 38391392.0000 - val_mean_absolute_error: 4182.4736
# Epoch 14/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 215100640.0000 - mean_absolute_error: 10839.8311 - val_loss: 19142776.0000 - val_mean_absolute_error: 2255.3132
# Epoch 15/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 212832576.0000 - mean_absolute_error: 10659.8398 - val_loss: 17892088.0000 - val_mean_absolute_error: 2117.7036
# Epoch 16/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 206550160.0000 - mean_absolute_error: 10572.0967 - val_loss: 17421972.0000 - val_mean_absolute_error: 2099.2959
# Epoch 17/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 201818864.0000 - mean_absolute_error: 10348.5049 - val_loss: 14831333.0000 - val_mean_absolute_error: 1650.1693
# Epoch 18/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 193547936.0000 - mean_absolute_error: 10330.8984 - val_loss: 15982590.0000 - val_mean_absolute_error: 2014.4568
# Epoch 19/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 189293440.0000 - mean_absolute_error: 10192.3047 - val_loss: 21900960.0000 - val_mean_absolute_error: 2890.5679
# Epoch 20/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 192162192.0000 - mean_absolute_error: 10190.0098 - val_loss: 15859132.0000 - val_mean_absolute_error: 2389.2920
# Epoch 21/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 188053072.0000 - mean_absolute_error: 10057.5742 - val_loss: 19906994.0000 - val_mean_absolute_error: 2964.9624
# Epoch 22/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 198847040.0000 - mean_absolute_error: 10136.6318 - val_loss: 16398443.0000 - val_mean_absolute_error: 1842.6007
# Epoch 23/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 195396320.0000 - mean_absolute_error: 10036.2656 - val_loss: 13079873.0000 - val_mean_absolute_error: 1433.6484
# Epoch 24/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 179898288.0000 - mean_absolute_error: 9955.2656 - val_loss: 19694406.0000 - val_mean_absolute_error: 2134.6111
# Epoch 25/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 178367744.0000 - mean_absolute_error: 9843.5244 - val_loss: 15748178.0000 - val_mean_absolute_error: 1875.5975
# Epoch 26/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 177595008.0000 - mean_absolute_error: 9963.7686 - val_loss: 12184824.0000 - val_mean_absolute_error: 1559.0757
# Epoch 27/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 183322800.0000 - mean_absolute_error: 9936.3340 - val_loss: 14478370.0000 - val_mean_absolute_error: 1484.4161
# Epoch 28/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 174545952.0000 - mean_absolute_error: 9729.8574 - val_loss: 17318666.0000 - val_mean_absolute_error: 2904.0508
# Epoch 29/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 176073104.0000 - mean_absolute_error: 9729.8760 - val_loss: 14560868.0000 - val_mean_absolute_error: 1782.7462
# Epoch 30/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 176708608.0000 - mean_absolute_error: 9809.0762 - val_loss: 14872773.0000 - val_mean_absolute_error: 1764.0231
# Epoch 31/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 167903856.0000 - mean_absolute_error: 9468.5820 - val_loss: 13262449.0000 - val_mean_absolute_error: 1482.8818
# Epoch 32/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 177723824.0000 - mean_absolute_error: 9634.2520 - val_loss: 19191622.0000 - val_mean_absolute_error: 2560.0945
# Epoch 33/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 163447008.0000 - mean_absolute_error: 9489.4912 - val_loss: 13135632.0000 - val_mean_absolute_error: 1833.2740
# Epoch 34/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 163780976.0000 - mean_absolute_error: 9446.2559 - val_loss: 14567474.0000 - val_mean_absolute_error: 1498.1796
# Epoch 35/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 169188976.0000 - mean_absolute_error: 9520.3154 - val_loss: 16390448.0000 - val_mean_absolute_error: 2399.9983
# Epoch 36/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 159909120.0000 - mean_absolute_error: 9354.9131 - val_loss: 12301862.0000 - val_mean_absolute_error: 1433.3208
# Epoch 37/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 162870672.0000 - mean_absolute_error: 9352.6748 - val_loss: 18724576.0000 - val_mean_absolute_error: 3009.8320
# Epoch 38/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 161853312.0000 - mean_absolute_error: 9250.5078 - val_loss: 15527429.0000 - val_mean_absolute_error: 1921.2012
# Epoch 39/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 157267040.0000 - mean_absolute_error: 9198.7305 - val_loss: 20558176.0000 - val_mean_absolute_error: 3212.2683
# Epoch 40/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 157976560.0000 - mean_absolute_error: 9211.9434 - val_loss: 14454702.0000 - val_mean_absolute_error: 1569.3889
# Epoch 41/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 159800176.0000 - mean_absolute_error: 9160.7969 - val_loss: 12981351.0000 - val_mean_absolute_error: 1565.3926
# Epoch 42/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 150679440.0000 - mean_absolute_error: 9065.3682 - val_loss: 12605849.0000 - val_mean_absolute_error: 1187.0605
# Epoch 43/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 153717792.0000 - mean_absolute_error: 9099.0557 - val_loss: 13568197.0000 - val_mean_absolute_error: 1412.2273
# Epoch 44/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 162838096.0000 - mean_absolute_error: 9298.3408 - val_loss: 16219039.0000 - val_mean_absolute_error: 2719.6108
# Epoch 45/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 153343712.0000 - mean_absolute_error: 9077.0215 - val_loss: 17823386.0000 - val_mean_absolute_error: 2597.3999
# Epoch 46/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 165560176.0000 - mean_absolute_error: 9296.1963 - val_loss: 16018688.0000 - val_mean_absolute_error: 1960.6270
# Epoch 47/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 159354496.0000 - mean_absolute_error: 9118.6016 - val_loss: 13477462.0000 - val_mean_absolute_error: 1542.0134
# Epoch 48/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 150367632.0000 - mean_absolute_error: 9018.9922 - val_loss: 17125914.0000 - val_mean_absolute_error: 2342.2671
# Epoch 49/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 150431280.0000 - mean_absolute_error: 8946.6738 - val_loss: 13002743.0000 - val_mean_absolute_error: 1518.2649
# Epoch 50/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 157246544.0000 - mean_absolute_error: 9090.6846 - val_loss: 15902589.0000 - val_mean_absolute_error: 2375.6260
# Epoch 51/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 148345232.0000 - mean_absolute_error: 9010.0820 - val_loss: 12953346.0000 - val_mean_absolute_error: 1302.4425
# Epoch 52/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 148352080.0000 - mean_absolute_error: 8899.0869 - val_loss: 18851338.0000 - val_mean_absolute_error: 2611.9207
# Epoch 53/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 148243056.0000 - mean_absolute_error: 8901.1777 - val_loss: 15076429.0000 - val_mean_absolute_error: 2258.9707
# Epoch 54/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 147304800.0000 - mean_absolute_error: 8903.2734 - val_loss: 13187570.0000 - val_mean_absolute_error: 1487.5769
# Epoch 55/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 150102144.0000 - mean_absolute_error: 8935.7930 - val_loss: 12957092.0000 - val_mean_absolute_error: 1564.8207
# Epoch 56/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 155562128.0000 - mean_absolute_error: 9152.8037 - val_loss: 14163330.0000 - val_mean_absolute_error: 1512.0787
# Epoch 57/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 153649568.0000 - mean_absolute_error: 9092.4658 - val_loss: 13543654.0000 - val_mean_absolute_error: 1363.9452
# Epoch 58/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 144454368.0000 - mean_absolute_error: 8754.0557 - val_loss: 13630571.0000 - val_mean_absolute_error: 2020.8562
# Epoch 59/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 153982880.0000 - mean_absolute_error: 9013.4277 - val_loss: 18632234.0000 - val_mean_absolute_error: 2693.9216
# Epoch 60/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 150370144.0000 - mean_absolute_error: 8957.7100 - val_loss: 12504942.0000 - val_mean_absolute_error: 1324.7362
# Epoch 61/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 153712672.0000 - mean_absolute_error: 9050.1562 - val_loss: 14153403.0000 - val_mean_absolute_error: 1798.1898
# Epoch 62/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 153659520.0000 - mean_absolute_error: 9035.3887 - val_loss: 15200850.0000 - val_mean_absolute_error: 2154.9971
# Epoch 63/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 148020192.0000 - mean_absolute_error: 8907.8311 - val_loss: 15636375.0000 - val_mean_absolute_error: 2483.3252
# Epoch 64/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 154756208.0000 - mean_absolute_error: 9022.6221 - val_loss: 12639349.0000 - val_mean_absolute_error: 1326.1833
# Epoch 65/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 148446992.0000 - mean_absolute_error: 8897.1992 - val_loss: 13064253.0000 - val_mean_absolute_error: 1609.8464
# Epoch 66/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 151677056.0000 - mean_absolute_error: 8927.9033 - val_loss: 14386573.0000 - val_mean_absolute_error: 1351.0902
# Epoch 67/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 151615360.0000 - mean_absolute_error: 8939.6768 - val_loss: 12519489.0000 - val_mean_absolute_error: 1473.0438
# Epoch 68/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 147393856.0000 - mean_absolute_error: 8815.1064 - val_loss: 13163498.0000 - val_mean_absolute_error: 1246.6027
# Epoch 69/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 145900032.0000 - mean_absolute_error: 8924.7871 - val_loss: 18789000.0000 - val_mean_absolute_error: 1416.6721
# Epoch 70/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 153249600.0000 - mean_absolute_error: 8974.8906 - val_loss: 14050661.0000 - val_mean_absolute_error: 1413.6880
# Epoch 71/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 143263808.0000 - mean_absolute_error: 8736.1660 - val_loss: 14816735.0000 - val_mean_absolute_error: 2315.2188
# Epoch 72/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 152866608.0000 - mean_absolute_error: 8953.1357 - val_loss: 13304364.0000 - val_mean_absolute_error: 1305.6598
# Epoch 73/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 144848016.0000 - mean_absolute_error: 8847.5732 - val_loss: 15765606.0000 - val_mean_absolute_error: 1786.1859
# Epoch 74/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 151321392.0000 - mean_absolute_error: 8802.1719 - val_loss: 14742760.0000 - val_mean_absolute_error: 2061.4214
# Epoch 75/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 150654912.0000 - mean_absolute_error: 8938.1367 - val_loss: 15569210.0000 - val_mean_absolute_error: 1978.7344
# Epoch 76/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 135992304.0000 - mean_absolute_error: 8602.4951 - val_loss: 17289822.0000 - val_mean_absolute_error: 2091.1404
# Epoch 77/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 145287744.0000 - mean_absolute_error: 8775.1152 - val_loss: 16099097.0000 - val_mean_absolute_error: 1778.8202
# Epoch 78/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 140948752.0000 - mean_absolute_error: 8759.6592 - val_loss: 16472713.0000 - val_mean_absolute_error: 2417.6931
# Epoch 79/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 143114032.0000 - mean_absolute_error: 8848.4004 - val_loss: 24248690.0000 - val_mean_absolute_error: 3392.7234
# Epoch 80/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 147120176.0000 - mean_absolute_error: 8941.0791 - val_loss: 16467894.0000 - val_mean_absolute_error: 2058.3850
# Epoch 81/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 146839136.0000 - mean_absolute_error: 8824.6885 - val_loss: 16490770.0000 - val_mean_absolute_error: 1645.4991
# Epoch 82/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 146416848.0000 - mean_absolute_error: 8830.3711 - val_loss: 13842158.0000 - val_mean_absolute_error: 1765.4866
# Epoch 83/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 141148480.0000 - mean_absolute_error: 8747.2725 - val_loss: 13919823.0000 - val_mean_absolute_error: 1863.9913
# Epoch 84/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 148580640.0000 - mean_absolute_error: 8949.3242 - val_loss: 15158846.0000 - val_mean_absolute_error: 1579.0277
# Epoch 85/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 142855552.0000 - mean_absolute_error: 8836.2402 - val_loss: 14500142.0000 - val_mean_absolute_error: 1735.8993
# Epoch 86/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 146666128.0000 - mean_absolute_error: 8987.5186 - val_loss: 13122285.0000 - val_mean_absolute_error: 1170.1449
# Epoch 87/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 143411360.0000 - mean_absolute_error: 8755.9551 - val_loss: 14196875.0000 - val_mean_absolute_error: 1609.5289
# Epoch 88/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 148331456.0000 - mean_absolute_error: 8851.8350 - val_loss: 17084912.0000 - val_mean_absolute_error: 1611.2615
# Epoch 89/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 143680832.0000 - mean_absolute_error: 8799.5049 - val_loss: 14191214.0000 - val_mean_absolute_error: 1338.2161
# Epoch 90/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 151410368.0000 - mean_absolute_error: 8935.7959 - val_loss: 16986898.0000 - val_mean_absolute_error: 2341.4792
# Epoch 91/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 153944080.0000 - mean_absolute_error: 8889.3574 - val_loss: 15043673.0000 - val_mean_absolute_error: 1647.9119
# Epoch 92/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 150084048.0000 - mean_absolute_error: 8795.9678 - val_loss: 16819632.0000 - val_mean_absolute_error: 1869.3319
# Epoch 93/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 145715856.0000 - mean_absolute_error: 8893.4424 - val_loss: 16455913.0000 - val_mean_absolute_error: 1763.0925
# Epoch 94/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 139133392.0000 - mean_absolute_error: 8771.9365 - val_loss: 18604330.0000 - val_mean_absolute_error: 2717.7234
# Epoch 95/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 142339040.0000 - mean_absolute_error: 8804.0576 - val_loss: 15651058.0000 - val_mean_absolute_error: 1537.6904
# Epoch 96/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 146403584.0000 - mean_absolute_error: 8825.7881 - val_loss: 16136371.0000 - val_mean_absolute_error: 1868.7814
# Epoch 97/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 140282720.0000 - mean_absolute_error: 8738.0234 - val_loss: 14272654.0000 - val_mean_absolute_error: 1590.3871
# Epoch 98/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 153724848.0000 - mean_absolute_error: 9005.0352 - val_loss: 15216012.0000 - val_mean_absolute_error: 2172.0579
# Epoch 99/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 150123952.0000 - mean_absolute_error: 9006.1699 - val_loss: 14264812.0000 - val_mean_absolute_error: 1867.4783
# Epoch 100/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 150132592.0000 - mean_absolute_error: 8912.3721 - val_loss: 18551292.0000 - val_mean_absolute_error: 2643.1926

# %%
# Evaluate the model on the test set
test_loss, test_mae = model.evaluate(X_test, y_test)
print(f"Test Mean Absolute Error: {test_mae}")
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 20943460.0000 - mean_absolute_error: 2809.9797
# Test Mean Absolute Error: 2723.0859375

# %%
# Plot training & validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()
