# %%
# Data manipulation and analysis
import pandas as pd
import numpy as np

# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Scikit-learn for preprocessing and model evaluation
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.pipeline import Pipeline

# TensorFlow and Keras for building the deep learning model
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Embedding, Flatten, LeakyReLU, Input
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2

# Optional: XGBoost for model comparison (if needed)
import xgboost as xgb

# Set visualization styles
sns.set(style="whitegrid")

# %%
df = pd.read_csv("/mnt/d/SalaryPredictionDataScientists/SalariesData/DataScience_salaries_2024.csv")

# %%
df.head()
# Out:
#    work_year experience_level employment_type                       job_title  \
# 0       2021               MI              FT                  Data Scientist
# 1       2021               MI              FT                 BI Data Analyst
# 2       2020               MI              FT                  Data Scientist
# 3       2021               MI              FT                     ML Engineer
# 4       2022               SE              FT  Lead Machine Learning Engineer
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  30400000             CLP          40038                 CL           100
# 1  11000000             HUF          36259                 HU            50
# 2  11000000             HUF          35735                 HU            50
# 3   8500000             JPY          77364                 JP            50
# 4   7500000             INR          95386                 IN            50
#
#   company_location company_size
# 0               CL            L
# 1               US            L
# 2               HU            L
# 3               JP            S
# 4               IN            L

# %%
# Check for missing values and data types
print("Dataset information:")
df.info()
# Out:
# Dataset information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14838 entries, 0 to 14837
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           14838 non-null  int64
#  1   experience_level    14838 non-null  object
#  2   employment_type     14838 non-null  object
#  3   job_title           14838 non-null  object
#  4   salary              14838 non-null  int64
#  5   salary_currency     14838 non-null  object
#  6   salary_in_usd       14838 non-null  int64
#  7   employee_residence  14838 non-null  object
#  8   remote_ratio        14838 non-null  int64
#  9   company_location    14838 non-null  object
#  10  company_size        14838 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 1.2+ MB

# %%
print("Summary statistics:")
df.describe()
# Out:
# Summary statistics:
#           work_year        salary  salary_in_usd  remote_ratio
# count  14838.000000  1.483800e+04   14838.000000  14838.000000
# mean    2023.138900  1.650227e+05  149874.718763     32.760480
# std        0.700799  3.562354e+05   69009.181349     46.488278
# min     2020.000000  1.400000e+04   15000.000000      0.000000
# 25%     2023.000000  1.021000e+05  102000.000000      0.000000
# 50%     2023.000000  1.422000e+05  141300.000000      0.000000
# 75%     2024.000000  1.875000e+05  185900.000000    100.000000
# max     2024.000000  3.040000e+07  800000.000000    100.000000

# %%
# Check for missing values in each column
print("Missing values per column:")
print(df.isnull().sum())
# Out:
# Missing values per column:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
#Pre-processing if needed for the given dataset

# Define columns based on data type
numerical_features = ['salary_in_usd']  # Add any other numerical columns if they exist
categorical_features = ['experience_level', 'employment_type', 'job_title', 'employee_residence']

# Fill missing numerical values with the median, and categorical with the most frequent value
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median'))
])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OneHotEncoder(handle_unknown='ignore'))
])

# Combine transformations into a preprocessor
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_features),
        ('cat', categorical_transformer, categorical_features)
    ]
)

# %%
# Transform categorical variables and prepare feature matrix X and target variable y
X = df.drop(columns=['salary'])  # Remove target column from features
y = df['salary_in_usd']  # Define target variable

# Apply transformations to features
X_prepared = preprocessor.fit_transform(X)

# Check the shape of the transformed features
print("Shape of transformed features:", X_prepared.shape)
# Out:
# Shape of transformed features: (14838, 250)

# %%
# Standardize the numerical features with with_mean=False
scaler = StandardScaler(with_mean=False)  # Set with_mean=False to handle sparse matrices
X_prepared = scaler.fit_transform(X_prepared)

# Check the first few rows to confirm transformation
print("Transformed feature matrix:")
print(X_prepared[:5])
# Out:
# Transformed feature matrix:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 25 stored elements and shape (5, 250)>
#   Coords	Values
#   (0, 0)	0.5802032201608008
#   (0, 3)	2.3432950833186106
#   (0, 7)	15.027396638488266
#   (0, 98)	2.485237303206165
#   (0, 177)	86.1394226519265
#   (1, 0)	0.5254405454770587
#   (1, 3)	2.3432950833186106
#   (1, 7)	15.027396638488266
#   (1, 30)	27.96334476701327
#   (1, 200)	60.913875838357235
#   (2, 0)	0.5178470970689399
#   (2, 3)	2.3432950833186106
#   (2, 7)	15.027396638488266
#   (2, 98)	2.485237303206165
#   (2, 200)	60.913875838357235
#   (3, 0)	1.1211059974154602
#   (3, 3)	2.3432950833186106
#   (3, 7)	15.027396638488266
#   (3, 123)	9.593840845668065
#   (3, 209)	43.07842313092561
#   (4, 0)	1.3822684539252246
#   (4, 4)	2.101420802721994
#   (4, 7)	15.027396638488266
#   (4, 122)	54.48486337586088
#   (4, 204)	14.195722091719437

# %%
# Split data into training and test sets (80-20 split)
X_train, X_test, y_train, y_test = train_test_split(X_prepared, y, test_size=0.2, random_state=42)

# Check the shape of each set
print("Training set shape:", X_train.shape, y_train.shape)
print("Testing set shape:", X_test.shape, y_test.shape)
# Out:
# Training set shape: (11870, 250) (11870,)
# Testing set shape: (2968, 250) (2968,)

# %%
# Save processed data to .npz files
np.savez("processed_data.npz", X_train=X_train, X_test=X_test, y_train=y_train, y_test=y_test)

# %%
# Define the model architecture
model = Sequential([
    Input(shape=(X_train.shape[1],)), 
    Dense(256, kernel_regularizer=l2(0.001)),
    LeakyReLU(negative_slope=0.1), 
    Dropout(0.3),
    
    Dense(128, kernel_regularizer=l2(0.001)),
    LeakyReLU(negative_slope=0.1), 
    Dropout(0.3),
    
    Dense(64, kernel_regularizer=l2(0.001)),
    LeakyReLU(negative_slope=0.1),  
    Dense(1) 
])

# %%
# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0005),
              loss='mean_squared_error',
              metrics=['mean_absolute_error'])

# %%
# Train the model
history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    verbose=1
)
# Out:
# Epoch 1/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 25627512832.0000 - mean_absolute_error: 143781.2656 - val_loss: 4906762240.0000 - val_mean_absolute_error: 51557.6797
# Epoch 2/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 3942367232.0000 - mean_absolute_error: 47169.3828 - val_loss: 3009841408.0000 - val_mean_absolute_error: 41563.9102
# Epoch 3/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3252876544.0000 - mean_absolute_error: 42127.6953 - val_loss: 2511633152.0000 - val_mean_absolute_error: 37345.1250
# Epoch 4/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2617774848.0000 - mean_absolute_error: 37371.6523 - val_loss: 2135805952.0000 - val_mean_absolute_error: 34613.9883
# Epoch 5/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 2307241984.0000 - mean_absolute_error: 35146.2383 - val_loss: 1842016384.0000 - val_mean_absolute_error: 31450.4062
# Epoch 6/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1974159616.0000 - mean_absolute_error: 32592.1055 - val_loss: 1595080704.0000 - val_mean_absolute_error: 29165.3809
# Epoch 7/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1671989632.0000 - mean_absolute_error: 30020.0762 - val_loss: 1331981056.0000 - val_mean_absolute_error: 26723.9961
# Epoch 8/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1356424192.0000 - mean_absolute_error: 27346.4727 - val_loss: 1028062080.0000 - val_mean_absolute_error: 23751.0723
# Epoch 9/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1104089344.0000 - mean_absolute_error: 24486.8672 - val_loss: 711014720.0000 - val_mean_absolute_error: 19661.0820
# Epoch 10/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 810317632.0000 - mean_absolute_error: 20580.1309 - val_loss: 411793760.0000 - val_mean_absolute_error: 14962.8223
# Epoch 11/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 510295904.0000 - mean_absolute_error: 16911.5723 - val_loss: 175029616.0000 - val_mean_absolute_error: 9759.3828
# Epoch 12/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 312372096.0000 - mean_absolute_error: 13182.7803 - val_loss: 60830728.0000 - val_mean_absolute_error: 5489.6694
# Epoch 13/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 228519104.0000 - mean_absolute_error: 11313.9355 - val_loss: 31983262.0000 - val_mean_absolute_error: 3737.8503
# Epoch 14/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 201567312.0000 - mean_absolute_error: 10534.8730 - val_loss: 19365690.0000 - val_mean_absolute_error: 2631.2585
# Epoch 15/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 195611392.0000 - mean_absolute_error: 10335.2139 - val_loss: 18326344.0000 - val_mean_absolute_error: 1891.2174
# Epoch 16/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 200167968.0000 - mean_absolute_error: 10354.0879 - val_loss: 17825208.0000 - val_mean_absolute_error: 1922.7825
# Epoch 17/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 193746288.0000 - mean_absolute_error: 10204.1377 - val_loss: 14369333.0000 - val_mean_absolute_error: 1615.2485
# Epoch 18/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 193979440.0000 - mean_absolute_error: 10297.9443 - val_loss: 23576756.0000 - val_mean_absolute_error: 3247.6343
# Epoch 19/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 196333968.0000 - mean_absolute_error: 10365.7988 - val_loss: 16705148.0000 - val_mean_absolute_error: 1881.2294
# Epoch 20/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 190908832.0000 - mean_absolute_error: 10193.5537 - val_loss: 16579304.0000 - val_mean_absolute_error: 1730.2090
# Epoch 21/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 185863584.0000 - mean_absolute_error: 9958.3262 - val_loss: 20734642.0000 - val_mean_absolute_error: 2358.2217
# Epoch 22/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 184359248.0000 - mean_absolute_error: 9931.6152 - val_loss: 18881272.0000 - val_mean_absolute_error: 2347.8796
# Epoch 23/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 182295456.0000 - mean_absolute_error: 9846.2861 - val_loss: 16230995.0000 - val_mean_absolute_error: 1712.2435
# Epoch 24/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 180451328.0000 - mean_absolute_error: 9865.6494 - val_loss: 17336406.0000 - val_mean_absolute_error: 1676.6769
# Epoch 25/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 174916080.0000 - mean_absolute_error: 9654.8701 - val_loss: 25925720.0000 - val_mean_absolute_error: 3896.0325
# Epoch 26/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 169409872.0000 - mean_absolute_error: 9646.9824 - val_loss: 22583654.0000 - val_mean_absolute_error: 2951.0540
# Epoch 27/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 185256144.0000 - mean_absolute_error: 10007.2734 - val_loss: 14536504.0000 - val_mean_absolute_error: 2027.3792
# Epoch 28/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 170813680.0000 - mean_absolute_error: 9687.1104 - val_loss: 17109992.0000 - val_mean_absolute_error: 1574.1741
# Epoch 29/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 187651680.0000 - mean_absolute_error: 9771.3916 - val_loss: 14301254.0000 - val_mean_absolute_error: 1678.3464
# Epoch 30/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 167711392.0000 - mean_absolute_error: 9484.0000 - val_loss: 19027092.0000 - val_mean_absolute_error: 2079.7908
# Epoch 31/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 164900912.0000 - mean_absolute_error: 9457.3867 - val_loss: 18572948.0000 - val_mean_absolute_error: 2621.3721
# Epoch 32/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 169511840.0000 - mean_absolute_error: 9583.8584 - val_loss: 16467965.0000 - val_mean_absolute_error: 1478.3896
# Epoch 33/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 166229168.0000 - mean_absolute_error: 9450.2881 - val_loss: 16956560.0000 - val_mean_absolute_error: 1571.9980
# Epoch 34/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 166373472.0000 - mean_absolute_error: 9500.3184 - val_loss: 13993152.0000 - val_mean_absolute_error: 1314.5129
# Epoch 35/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 157998656.0000 - mean_absolute_error: 9280.4668 - val_loss: 17653176.0000 - val_mean_absolute_error: 2452.7078
# Epoch 36/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 155679760.0000 - mean_absolute_error: 9189.1074 - val_loss: 19472256.0000 - val_mean_absolute_error: 2842.3960
# Epoch 37/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 161361488.0000 - mean_absolute_error: 9232.5557 - val_loss: 16364188.0000 - val_mean_absolute_error: 1717.2781
# Epoch 38/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 153954032.0000 - mean_absolute_error: 9153.2314 - val_loss: 17592326.0000 - val_mean_absolute_error: 2339.8752
# Epoch 39/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 153560288.0000 - mean_absolute_error: 9138.3525 - val_loss: 26783164.0000 - val_mean_absolute_error: 3369.1531
# Epoch 40/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 170024736.0000 - mean_absolute_error: 9461.5693 - val_loss: 16020978.0000 - val_mean_absolute_error: 1526.9885
# Epoch 41/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 159473296.0000 - mean_absolute_error: 9209.6445 - val_loss: 18704022.0000 - val_mean_absolute_error: 2132.6113
# Epoch 42/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 156990160.0000 - mean_absolute_error: 9135.4355 - val_loss: 15633421.0000 - val_mean_absolute_error: 1606.2206
# Epoch 43/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 155952816.0000 - mean_absolute_error: 9181.7617 - val_loss: 16827644.0000 - val_mean_absolute_error: 1929.1060
# Epoch 44/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 146617520.0000 - mean_absolute_error: 9030.9385 - val_loss: 20318644.0000 - val_mean_absolute_error: 2463.3755
# Epoch 45/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 149361456.0000 - mean_absolute_error: 8894.9150 - val_loss: 25738604.0000 - val_mean_absolute_error: 3542.8101
# Epoch 46/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 153809728.0000 - mean_absolute_error: 9181.5332 - val_loss: 17854684.0000 - val_mean_absolute_error: 1470.5328
# Epoch 47/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 143779232.0000 - mean_absolute_error: 8863.2412 - val_loss: 18042168.0000 - val_mean_absolute_error: 1784.7799
# Epoch 48/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 154991408.0000 - mean_absolute_error: 9012.9492 - val_loss: 20110550.0000 - val_mean_absolute_error: 2703.3284
# Epoch 49/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 154190128.0000 - mean_absolute_error: 9063.7070 - val_loss: 17351272.0000 - val_mean_absolute_error: 2457.7234
# Epoch 50/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 151382896.0000 - mean_absolute_error: 8973.4795 - val_loss: 16154560.0000 - val_mean_absolute_error: 2106.9670
# Epoch 51/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 153181680.0000 - mean_absolute_error: 9128.3877 - val_loss: 18771082.0000 - val_mean_absolute_error: 2364.4568
# Epoch 52/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 148011040.0000 - mean_absolute_error: 8813.0303 - val_loss: 14722239.0000 - val_mean_absolute_error: 1399.0880
# Epoch 53/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 145992480.0000 - mean_absolute_error: 8836.8857 - val_loss: 15268559.0000 - val_mean_absolute_error: 1825.0575
# Epoch 54/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 147600144.0000 - mean_absolute_error: 8990.4150 - val_loss: 11977742.0000 - val_mean_absolute_error: 1385.8440
# Epoch 55/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 144653424.0000 - mean_absolute_error: 8923.0869 - val_loss: 15779279.0000 - val_mean_absolute_error: 1943.9178
# Epoch 56/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 159677744.0000 - mean_absolute_error: 9241.2812 - val_loss: 14815441.0000 - val_mean_absolute_error: 1350.2837
# Epoch 57/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 148651776.0000 - mean_absolute_error: 9072.0625 - val_loss: 15952683.0000 - val_mean_absolute_error: 2003.2363
# Epoch 58/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 149460880.0000 - mean_absolute_error: 9059.9150 - val_loss: 20532124.0000 - val_mean_absolute_error: 3043.5405
# Epoch 59/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 149494656.0000 - mean_absolute_error: 8844.2441 - val_loss: 12648812.0000 - val_mean_absolute_error: 1430.9099
# Epoch 60/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 157424704.0000 - mean_absolute_error: 9083.3115 - val_loss: 15675033.0000 - val_mean_absolute_error: 1484.4801
# Epoch 61/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 138708064.0000 - mean_absolute_error: 8686.3867 - val_loss: 15120408.0000 - val_mean_absolute_error: 1434.2144
# Epoch 62/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 152442192.0000 - mean_absolute_error: 8927.8301 - val_loss: 17874086.0000 - val_mean_absolute_error: 1736.0251
# Epoch 63/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 142848656.0000 - mean_absolute_error: 8840.9463 - val_loss: 18594878.0000 - val_mean_absolute_error: 1535.5020
# Epoch 64/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 154117824.0000 - mean_absolute_error: 9008.2764 - val_loss: 20396452.0000 - val_mean_absolute_error: 1615.2892
# Epoch 65/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 147109728.0000 - mean_absolute_error: 8829.6084 - val_loss: 17785362.0000 - val_mean_absolute_error: 2606.8689
# Epoch 66/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 149155392.0000 - mean_absolute_error: 8970.0869 - val_loss: 17133256.0000 - val_mean_absolute_error: 2205.3391
# Epoch 67/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 158264624.0000 - mean_absolute_error: 9037.1670 - val_loss: 19072036.0000 - val_mean_absolute_error: 2548.1665
# Epoch 68/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 152521840.0000 - mean_absolute_error: 9072.0986 - val_loss: 15189738.0000 - val_mean_absolute_error: 1566.5940
# Epoch 69/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 150614928.0000 - mean_absolute_error: 8903.2510 - val_loss: 21465638.0000 - val_mean_absolute_error: 2625.0046
# Epoch 70/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 151132128.0000 - mean_absolute_error: 9006.0820 - val_loss: 17338236.0000 - val_mean_absolute_error: 1928.0101
# Epoch 71/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 156498064.0000 - mean_absolute_error: 8889.7168 - val_loss: 14565235.0000 - val_mean_absolute_error: 1656.9943
# Epoch 72/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 145812256.0000 - mean_absolute_error: 8863.9375 - val_loss: 16820102.0000 - val_mean_absolute_error: 1831.2224
# Epoch 73/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 151594880.0000 - mean_absolute_error: 9028.8223 - val_loss: 17421850.0000 - val_mean_absolute_error: 1667.8131
# Epoch 74/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 138840512.0000 - mean_absolute_error: 8659.1289 - val_loss: 16101027.0000 - val_mean_absolute_error: 1508.3324
# Epoch 75/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 147046480.0000 - mean_absolute_error: 8917.4062 - val_loss: 23285352.0000 - val_mean_absolute_error: 3027.5491
# Epoch 76/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 141812368.0000 - mean_absolute_error: 8922.0391 - val_loss: 18495378.0000 - val_mean_absolute_error: 2578.2017
# Epoch 77/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 158134416.0000 - mean_absolute_error: 9162.3848 - val_loss: 16932512.0000 - val_mean_absolute_error: 2227.0830
# Epoch 78/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 148016176.0000 - mean_absolute_error: 8731.6914 - val_loss: 16822158.0000 - val_mean_absolute_error: 1380.2118
# Epoch 79/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 148577392.0000 - mean_absolute_error: 8941.7012 - val_loss: 15673715.0000 - val_mean_absolute_error: 1455.1309
# Epoch 80/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 146711984.0000 - mean_absolute_error: 8905.9326 - val_loss: 16748302.0000 - val_mean_absolute_error: 2112.7585
# Epoch 81/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 149324544.0000 - mean_absolute_error: 8872.2324 - val_loss: 17471084.0000 - val_mean_absolute_error: 2334.5686
# Epoch 82/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 146056656.0000 - mean_absolute_error: 8854.3652 - val_loss: 16462214.0000 - val_mean_absolute_error: 2215.9551
# Epoch 83/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 139408880.0000 - mean_absolute_error: 8730.0000 - val_loss: 15706059.0000 - val_mean_absolute_error: 1717.8047
# Epoch 84/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 152314576.0000 - mean_absolute_error: 9047.1094 - val_loss: 21971974.0000 - val_mean_absolute_error: 2105.5930
# Epoch 85/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 144668688.0000 - mean_absolute_error: 8840.1553 - val_loss: 12965179.0000 - val_mean_absolute_error: 1514.5894
# Epoch 86/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 148708464.0000 - mean_absolute_error: 8792.6035 - val_loss: 14605466.0000 - val_mean_absolute_error: 1608.3892
# Epoch 87/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 151075520.0000 - mean_absolute_error: 8950.3320 - val_loss: 12792420.0000 - val_mean_absolute_error: 1394.6675
# Epoch 88/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 145333552.0000 - mean_absolute_error: 8813.7754 - val_loss: 14778470.0000 - val_mean_absolute_error: 1980.4880
# Epoch 89/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 155843904.0000 - mean_absolute_error: 9164.0723 - val_loss: 17195450.0000 - val_mean_absolute_error: 1541.1564
# Epoch 90/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 144729728.0000 - mean_absolute_error: 8893.9668 - val_loss: 19051240.0000 - val_mean_absolute_error: 1810.2933
# Epoch 91/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 149828688.0000 - mean_absolute_error: 8958.7666 - val_loss: 15419175.0000 - val_mean_absolute_error: 1499.1138
# Epoch 92/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 139538768.0000 - mean_absolute_error: 8749.0479 - val_loss: 15478177.0000 - val_mean_absolute_error: 2262.6343
# Epoch 93/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 133258800.0000 - mean_absolute_error: 8490.2422 - val_loss: 15259638.0000 - val_mean_absolute_error: 1558.3433
# Epoch 94/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 143993504.0000 - mean_absolute_error: 8863.9961 - val_loss: 13994695.0000 - val_mean_absolute_error: 1411.9154
# Epoch 95/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 142005136.0000 - mean_absolute_error: 8742.1963 - val_loss: 16589958.0000 - val_mean_absolute_error: 1987.3485
# Epoch 96/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 145354544.0000 - mean_absolute_error: 8886.2002 - val_loss: 15603414.0000 - val_mean_absolute_error: 1849.4274
# Epoch 97/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 148870112.0000 - mean_absolute_error: 8914.5908 - val_loss: 15212090.0000 - val_mean_absolute_error: 1889.3909
# Epoch 98/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 148137232.0000 - mean_absolute_error: 8907.9600 - val_loss: 18280430.0000 - val_mean_absolute_error: 2549.3462
# Epoch 99/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 140780432.0000 - mean_absolute_error: 8701.9922 - val_loss: 17243934.0000 - val_mean_absolute_error: 1908.4111
# Epoch 100/100
# 297/297 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 143398944.0000 - mean_absolute_error: 8753.1562 - val_loss: 22162350.0000 - val_mean_absolute_error: 2778.6702

# %%
# Evaluate the model on the test set
test_loss, test_mae = model.evaluate(X_test, y_test)
print(f"Test Mean Absolute Error: {test_mae}")
# Out:
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 20249952.0000 - mean_absolute_error: 2886.3843
# Test Mean Absolute Error: 2823.99658203125

# %%
# Plot training & validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.show()
